# %% [markdown]
# #                                                  SQL
# ###  Total Points = 78

# %% [markdown]
# SQL stands for the structured query language.
#
# SQL is the standardized language used to access the database.
#
# ANSI/SQL defines the SQL standard. The current version of SQL is SQL:2016. Whenever we refer to the SQL standard, we mean the current SQL version.
#
# SQL contains three parts:
#
# 1)Data Definition
# 2)Data manipulation
# 3)Data control
#
# Data definition language includes statements that help you define the database and its objects, e.g., tables, views, triggers, stored procedures, etc.
# Data manipulation language contains statements that allow you to update and query data.
# Data control language allows you to grant the permissions to a user to access specific data in the database.

# %% [markdown]
# Follow instructions below:
# 1. For questions and dataset, click on excercise links given in respective topics. Click Begin button upon landing on the page.
# 2. To navigate within a particular excercise, you can find previous and next exercise links on both  top and bottom of the page.
# 2. For every topic, first solve the question mentioned in https://pgexercises.com/ in exercises under respective headings for your practice, try to solve it and understand the mistakes with the help of answer and discussion part given under every question.
# 3. Then solve the question assigned under every heading in this notebook for the same respective dataset and and write your solution here. The output format is attached below every question here.
# 4. Each question is of two marks so attempt carefully.
# 5. After completing the assignment submit it accordingly.

# %% [markdown]
# STUDY MATERIALS:
# 1. https://www.w3schools.com/sql/default.asp
# 2. https://www.youtube.com/watch?v=taMe4NMsOn8&list=PLbGui_ZYuhigbr-fJ_9HlOqwg0S24Z73-

# %% [markdown]
# Practice the following questions to enhance your SQL based skills!

# %% [markdown]
# ## 1. Basics
#
# Exercise link: https://pgexercises.com/questions/basic/

# %% [markdown]
# <p style='text-align: right;'> 16 points</p>

# %% [markdown]
# Reference:- https://www.youtube.com/watch?v=Z_hEj2U_5tI

# %% [markdown]
# (a) Write an SQL statement to retrieve a list of only slots and start time of bookings(Print first five rows only).

# %% [raw]
# #write your query
#
# select slots,starttime from cd.bookings
# limit 5;

# %% [markdown]
# ![1a.png](attachment:1a.png)

# %% [markdown]
# (b)Retrieve the name of facilities with monthly maintainence greater than 1000.

# %% [raw]
# #write your query
#
# select name from cd.facilities
# where monthlymaintenance>1000;

# %% [markdown]
# ![1b.png](attachment:1b.png)

# %% [markdown]
# (c) How can you produce a list of facilities that charge a fee to members, and that fee is  less than one fourth of the guestcost as well as the monthlymaintenance is less than 100? Return the facid, facility name, member cost, and monthly maintenance of the facilities in question.

# %% [raw]
# #write your query
#
# select facid, name, membercost, monthlymaintenance from cd.facilities
# where membercost>0 and (membercost<guestcost/4.0 and monthlymaintenance<100);

# %% [markdown]
# ![1c.png](attachment:1c.png)

# %% [markdown]
# (d) How can you produce a list of all facilities with the letter 'T' and letter 'P' in their name?

# %% [raw]
# #write your query
#
# select * from cd.facilities
# where name LIKE '%T%' and
#       (name LIKE '%P%') ;

# %% [markdown]
# ![1d.png](attachment:1d.png)

# %% [markdown]
# (e) How can you retrieve the details of all the bookings with face id greater than 1 and less than 4 without using AND operator?

# %% [raw]
# #write your query
#
# select * from cd.bookings
# where facid in (2,3);

# %% [markdown]
# ![1e.png](attachment:1e.png)

# %% [markdown]
# (f). How can you produce a list of bookings, with each labelled as 'available' or 'not available' depending on if their slots lies in range of 2 to 5( 2 and 5 not included) ? Return all the details of such bookings.

# %% [raw]
# #write your query
#
# select *,
#        case
# 	      when(slots<=2) then
# 	        'not available'
# 	      when (slots>=5) then
# 	        'not available'
# 	   else
# 	      'available'
# 	   end as slots
# 	   from cd.bookings;

# %% [markdown]
# ![1g.png](attachment:1g.png)

# %% [markdown]
# (g) How can you produce a list of booking with start time between august 2012 and end of october 2012? Return facid,memid and starttime for the given question.(Here the output will contain more rows , all rows cannot be shown below)

# %% [raw]
# #write your query
#
# select facid,memid, starttime from cd.bookings
# where starttime>'2012-08-01' and
#       (starttime<'2012-10-31');

# %% [markdown]
# ![1i.png](attachment:1i.png)

# %% [markdown]
#  (h) How can you produce an ordered list of the first 3 slots in the booking table with facid greater than 2? The list must not contain duplicates.(Return facid,memid,slots)

# %% [raw]
# #write your query
#
# select distinct facid,  memid, slots from cd.bookings
# where facid>2
# order by slots asc
# limit 3;

# %% [markdown]
# ![1j.png](attachment:1j.png)

# %% [markdown]
# ## 2.Joins and subqueries
#
# Exercise link: https://pgexercises.com/questions/joins/

# %% [markdown]
# <p style='text-align: right;'> 10 points</p>

# %% [markdown]
# Reference:-
# 1. https://www.youtube.com/watch?v=Jh_pvk48jHA
# 2. https://youtu.be/zYH-e6tUYbw

# %% [markdown]
# (a). How can you produce a list of the first five start times for bookings by members?

# %% [raw]
# #write your query
#
# select starttime from cd.bookings
# limit 5;

# %% [markdown]
# ![2a.png](attachment:2a.png)

# %% [markdown]
# (b). How can you produce a list of the name and their member cost for facilities with booking slots greater than 3 and guestcost>10?( output below contains few rows of total output just for reference)

# %% [raw]
# #write your query
#
# select facs.name, facs.membercost
# from cd.facilities facs
#      inner join cd.bookings bks
# 	 on facs.facid = bks.facid
# where bks.slots > 3 and
#      (facs.guestcost>10);

# %% [markdown]
# ![1k.png](attachment:1k.png)

# %% [markdown]
# (c) How can you output a list of firstname of all members who have recommended another member and the joindate of members who have recommended others is  between september 2012 and end of october 2012? Ensure that there are no duplicates in the list, and that results are ordered by firstname.

# %% [raw]
# #write your query
#
# select distinct mems.firstname
# from
#      cd.members mems
# 	 inner join cd.members recs
# 	     on mems.memid = recs.recommendedby
# where recs.joindate >= '2012-09-01' and
#        (recs.joindate <= '2012-10-31')
# order by mems.firstname;

# %% [markdown]
# ![2c.png](attachment:2c.png)

# %% [markdown]
# (d) How can you produce a list of all members who have used a badminton court and table tennis and the member cost is zero ? Include in your output the name of the court, and the name of the member formatted as a single column. Ensure no duplicate data, and order by the member name followed by the facility name.

# %% [raw]
# #write your query
#
# select distinct concat(mems.firstname,' ',mems.surname) as member, facs.name as facility
# from
#     cd.members mems
# 	inner join cd.bookings bks
# 	      on mems.memid = bks.memid
# 	inner join cd.facilities facs
# 	      on bks.facid = facs.facid
#
# where
#     facs.name in ('Badminton Court', 'Table Tennis') and
# 	(facs.membercost = 0)
#
# order by member, facility;

# %% [markdown]
# ![2d.png](attachment:2d.png)

# %% [markdown]
# (e) How can you produce a list of all members who have used a tennis court? Include in your output the name of the court, and the name of the member formatted as a single column. Ensure no duplicate data, and order by the member name followed by the facility name.

# %% [raw]
# #write your query
#
# select distinct concat(mems.firstname,' ',mems.surname) as member, facs.name as facility
# from
#     cd.members mems
# 	inner join cd.bookings bks
# 	      on mems.memid = bks.memid
# 	inner join cd.facilities facs
# 	      on bks.facid = facs.facid
#
# where
#     facs.name in ('Tennis Court 1', 'Tennis Court 2')
# order by member, facility;

# %% [markdown]
# ![8a.png](attachment:8a.png)

# %% [markdown]
# ## 3. Modifying Data
#
# Exercise link: https://pgexercises.com/questions/updates/

# %% [markdown]
# <p style='text-align: right;'> 16 points</p>

# %% [markdown]
# Reference:-
# 1. https://www.youtube.com/watch?v=G3v82C6ThlM
# 2. https://www.youtube.com/watch?v=R8EeH46xuOg

# %% [markdown]
# (a) Add a new data to the facilities table. Use the following values:
#
# facid: 10, Name: 'Spa 2', membercost: 10, guestcost: 50, initialoutlay: 10000, monthlymaintenance: 500.

# %% [raw]
# #write your query
#
# insert into cd.facilities
#     (facid, name, membercost, guestcost, initialoutlay, monthlymaintenance)
#     values (10, 'Spa 2', 10, 50, 10000, 500);

# %% [markdown]
# ![2e.png](attachment:2e.png)

# %% [markdown]
# (b) Insert multiple rows in table facilities :
# Use the following values:
#
# 1. facid: 11, Name: 'Lawn tennis', membercost: 50, guestcost: 40, initialoutlay: 200000, monthlymaintenance: 600.
# 2. facid: 12, Name: 'Squash Court 2', membercost: 6.5, guestcost: 27.5, initialoutlay: 6000, monthlymaintenance: 800.

# %% [raw]
# #write your query
#
# insert into cd.facilities
#     (facid, name, membercost, guestcost, initialoutlay, monthlymaintenance)
#     values (11, 'Lawn tennis', 50, 40, 200000, 600),
#            (12,'Squash Court 2', 6.5, 27.5, 6000,800);

# %% [markdown]
# ![2g.png](attachment:2g.png)

# %% [markdown]
# (c) Update the data in table facilities for facid =3 , changeguest cost to 30 and membercost to 10.

# %% [raw]
# #write your query
#
# update cd.facilities
# set
#    guestcost = 30,
#    membercost = 10
# where facid =3;
#
# ## Note ---> Ans given below is for facid = 1 and not for facid = 3.

# %% [markdown]
# ![3a.png](attachment:3a.png)

# %% [markdown]
# (d) We want to alter the price of the badminton court for facid 3 so that it costs 20% less than the price of tennis court 2 for facid= 2. Try to do this without using constant values for the prices, so that we can reuse the statement if we want to.

# %% [raw]
# #write your query
#
#
# update cd.facilities facs
#        set
# 	     membercost = (select membercost*0.8 from cd.facilities where facid = 2),
# 		 guestcost = (select guestcost*0.8 from cd.facilities where facid = 2)
# 	   where facs.facid = 3;
#
#
# ## Note --> Ans given below is corresponding to the below code, but according to question above code should be the answer
#
#
# update cd.facilities facs
#        set
# 	     membercost = (select membercost*1.2 from cd.facilities where facid = 1),
# 		 guestcost = (select guestcost*1.2 from cd.facilities where facid = 1)
# 	   where facs.facid = 2;

# %% [markdown]
# ![3b.png](attachment:3b.png)

# %% [markdown]
# (e)Delete all details of facilities from the cd.facilities table( without using delete statement)

# %% [raw]
# #write your query
#
# truncate table cd.facilities cascade;

# %% [markdown]
# (f)We want to remove member 44, who has never made a booking, from our database. How can we achieve that?

# %% [raw]
# #write your code
#
# delete from cd.members where memid = 44;

# %% [markdown]
# (g)Delete all bookings

# %% [raw]
# #write your code
#
# delete from cd.bookings;

# %% [markdown]
# (h). How to delete all members who have never made a booking?

# %% [raw]
# #write your code
#
# delete from cd.members
# where memid not in (select memid from cd.bookings);

# %% [markdown]
# ## 4. Aggregates
#
# Exercise link: https://pgexercises.com/questions/aggregates/

# %% [markdown]
# <p style='text-align: right;'> 12 points</p>

# %% [markdown]
# Reference:
# 1. https://www.youtube.com/watch?v=jcoJuc5e3RE
# 2. https://www.youtube.com/watch?v=nNrgRVIzeHg

# %% [markdown]
# (a)Count the number of members

# %% [raw]
# # write your code
#
# select count(*) from cd.members;

# %% [markdown]
# ![4a.png](attachment:4a.png)

# %% [markdown]
# (b)Produce a count of the number of facilities that have maintenance cost greater than 100 and guest cost of 20 or more.

# %% [raw]
# # write your code
#
# select count(*) from cd.facilities
#      where monthlymaintenance>100
# 	     and guestcost >= 20;

# %% [markdown]
# ![4c.png](attachment:4c.png)

# %% [markdown]
# (c)Produce a list of facilities with more than 1000 slots booked and start time after 1st of august 2012. Produce an output table consisting of facility id and slots, sorted by facility id.

# %% [raw]
# #write your code
#
# select facid, sum(slots) as "Total Slots"
#        from cd.bookings
# 	   where starttime > '2012-08-01'
# 	   group by facid
# 	   having sum(slots)>1000
# order by facid;

# %% [markdown]
# ![4i.png](attachment:4i.png)

# %% [markdown]
# (d) Find the total number of distinct facilities with monthly maintenance greater than 100.

# %% [raw]
# #write your code
#
# select distinct count(*) from cd.facilities
# where monthlymaintenance>100;

# %% [markdown]
# ![4e.png](attachment:4e.png)

# %% [markdown]
# (e) Solve the following:
# 1. List the total slots booked per facility in the month of august 2012

# %% [raw]
# # write code for first part
#
# select facid, sum(slots) as "Total Slots"
# from cd.bookings
# where starttime>='2012-08-01' and
#       (starttime<'2012-09-01')
# group by facid
# order by sum(slots);

# %% [markdown]
# ![4f.png](attachment:4f.png)

# %% [markdown]
# (f) Solve the following:
# 1. calculate the amount of time each facility will take to repay its cost of ownership. Remember to take into account ongoing monthly maintenance. Output facility name and payback time in months, order by facility name. Don't worry about differences in month lengths, we're only looking for a rough value here!

# %% [raw]
# # write code for first part
#
#
# select facs.name as name,
#        facs.initialoutlay/((sum(case
# 								when memid = 0 then slots*facs.guestcost
# 								else slots*membercost
# 								end)/3) - facs.monthlymaintenance) as months
# 	   from cd.bookings bks
# 	   inner join cd.facilities facs
# 	         on bks.facid = facs.facid
# 	   group by facs.facid
# order by name;

# %% [markdown]
# ![4g.png](attachment:4g.png)

# %% [markdown]
# ## 5. Date
#
# Exercise link: https://pgexercises.com/questions/date/

# %% [markdown]
#  <p style='text-align: right;'> 14 points</p>

# %% [markdown]
# Reference- https://www.mysqltutorial.org/mysql-timestamp.aspx#:~:text=The%20MySQL%20TIMESTAMP%20is%20a,%3A14%3A07'%20UTC%20.

# %% [markdown]
# (a) Produce a timestamp for 2 a.m. on the 16st of september 2012

# %% [raw]
# # write your code here
#
# select timestamp '2012-09-16 02:00:00';

# %% [markdown]
# ![5a.png](attachment:5a.png)

# %% [markdown]
# (b) Find the result of subtracting the timestamp '2012-09-30 02:00:00' from the timestamp '2012-10-31 02:00:00'

# %% [raw]
# # write your code
#
# select timestamp '2012-10-31 02:00:00'- timestamp '2012-09-30 02:00:00' as interval;

# %% [markdown]
# ![5b.png](attachment:5b.png)

# %% [markdown]
# (c) Produce a list of all the dates in september 2012. They can be output as a timestamp (with time set to midnight) or a date.

# %% [raw]
# # write your code
#
# select generate_series(timestamp '2012-09-01',timestamp '2012-09-30',interval '1 day') as ts;

# %% [markdown]
# ![5d.png](attachment:5d.png)

# %% [markdown]
# (d) Get the day of the month from the timestamp '2012-09-30' as an integer.

# %% [raw]
# # write your code
#
# select extract(day from timestamp '2012-09-30');

# %% [markdown]
# ![5f.png](attachment:5f.png)

# %% [markdown]
# (e) Solve the following:
# 1. Work out the number of seconds between the timestamps '2012-08-25 01:00:00' and '2012-09-25 00:00:00'

# %% [raw]
# # write your code
#
# select extract(epoch from (timestamp '2012-09-25 00:00:00'- timestamp '2012-08-25 01:00:00')) as date_part;

# %% [markdown]
# ![5g.png](attachment:5g.png)

# %% [markdown]
# (f) Solve the following :
# 1. For any given timestamp, work out the number of days remaining in the month. The current day should count as a whole day, regardless of the time. Use '2012-08-10 02:30:00' as an example timestamp for the purposes of making the answer. Format the output as a single interval value.

# %% [raw]
# # write your code
#
# select (date_trunc('month', ts.test)+interval '1 month') - date_trunc('day', ts.test) as remaining
#   from (select timestamp '2012-08-10 02:30:00' as test) ts;

# %% [markdown]
# ![5k.png](attachment:5k.png)

# %% [markdown]
# (g). Return a count of bookings for each month, sorted by month.

# %% [raw]
# #write your code
#
# select date_trunc('month',starttime) as month, count(*)
#      from cd.bookings
# 	 group by month
# 	 order by month;

# %% [markdown]
# ![7A.png](attachment:7A.png)

# %% [markdown]
# ## 6. Strings
#
#
# Exercise link:https://pgexercises.com/questions/string/

# %% [markdown]
# <p style='text-align: right;'> 10 points</p>

# %% [markdown]
# Reference-
# 1. https://www.youtube.com/watch?v=3d4f6HNKj-8
# 2. https://www.youtube.com/watch?v=6Fj7am_-E8k
# 3. https://www.w3schools.com/sql/sql_wildcards.asp

# %% [markdown]
# (a). Output the names of all members, formatted as 'Surname, Firstname','Surname'

# %% [raw]
# # write your code
#
# select concat(surname,', ',firstname,',',surname) as name from cd.members;

# %% [markdown]
# ![5l.png](attachment:5l.png)

# %% [markdown]
# (b)Find all facilities whose name ends  with 'Court'. Retrieve all columns.

# %% [raw]
# # write your code
#
# select * from cd.facilities
# where name like '%Court';

# %% [markdown]
# ![5m.png](attachment:5m.png)

# %% [markdown]
# (c)Find all facilities whose name starts with Badminton and ends  with 'Court'. Retrieve all columns.

# %% [raw]
# # write your code
#
# select * from cd.facilities
# where name like 'Badminton%Court';

# %% [markdown]
# ![6a.png](attachment:6a.png)

# %% [markdown]
# (d) You'd like to produce a count of how many members you have whose surname starts with each letter of the alphabet. Sort by the letter, and don't worry about printing out a letter if the count is 0.

# %% [raw]
# # write your code
#
# select substr (mems.surname,1,1) as letter, count(*) as count
#     from cd.members mems
#     group by letter
#     order by letter;

# %% [markdown]
# ![6b.png](attachment:6b.png)

# %% [markdown]
# (e). You've noticed that the club's member table has telephone numbers with very inconsistent formatting. You'd like to find all the telephone numbers that contain parentheses, returning the member ID and telephone number sorted by member ID.

# %% [raw]
# #write your code
#
# select memid, telephone from cd.members where telephone ~ '[()]' order by memid;

# %% [markdown]
# ![6f.png](attachment:6f.png)

# %% [markdown]
# ---------------------------------
#
# # Give youself a treat:) Congratulations! you have completed the SQL challenge.
#
# --------------------------------
#
# # FeedBack
# We hope you’ve enjoyed this course so far. We’re committed to help you use "AI for All" course to its full potential, so that you have a great learning experience. And that’s why we need your help in form of a feedback here.
#
# Please fill this feedback form  https://zfrmz.in/MtRG5oWXBdesm6rmSM7N
